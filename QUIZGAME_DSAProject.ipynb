# %% [markdown]
# <a href="https://colab.research.google.com/github/Matthew-Ilustre/DSA-58011/blob/main/QUIZGAME_DSAProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sq1 =1
sq2 =1
sq3 =1
sq4 =1
sq5 =1
sq6 =1
sq7 =1
sq8 =1
sq9 =1
sq10 =1
Game = [p1,p2,p3]
score = [sq1,sq2,sq3,sq4,sq5,sq6,sq7,sq8,sq9,sq10]

name = input('Good Day Testee who might you be? ' )

class menu:
  MENU = input('do you wish to test your knowledge? Y/N ')
  if (MENU == "Y" or MENU =="y"):
    p1()

  elif (MENU == "N" or MENU == "n"):
    print('Thank you for viewing.', name)

  else:
    print('Input unrecognized please try again.')







def p1():
  
  print("The term ‘Computer’ is derived from?")

  q1 = input("A.LATIN B.ENGLISH \nC.GREEK D.SPANISH \n")


  if (q1 =='A' or q1 =='a'):
    
    print("GOOD JOB SMART BUTT")
  elif(q1 =='B' or q1 =='b'or q1 =='C' or q1 =='c' or q1 =='D' or q1 =='d'):
    tsq1 = sq1 - 1
    score.pop(sq1)
    print("incorrect answer it is A.LATIN")
  else:
	  print("INVALID INPUT")

  input("PRESS ENTER TO CONTINUE")
  

  print("Who is the father of Computer?")
  q2 = input("A.Rudy Siguenza B.Allen Turing \nC.Charles Babbage D.Edward Robert \n")

  if (q2 =='C' or q2 =='c'):
    
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q2 =='B' or q2 =='b'or q2 =='A' or q2 =='a' or q2 =='D' or q2 =='d'):
    tsq2 = sq2 - 1
    score.pop(sq2)
    print("incorrect answer it is C.Charles Babbage")
  else:
	  print("INVALID INPUT")
   
  input("PRESS ENTER TO CONTINUE")
  dialogue1()



def dialogue1():
  input("\n \n \nCongrats answering the easy questions let us make it harder \n PRESS ENTER TO CONTINUE \n")
  p2()




def p2():
  
  
  print("Who is the father of Computer science?")
  q3 = input("A.Charles Babbage B.Allen Turing \nC.Edward Robert D.Albert Einstein \n")

  if (q3 =='B' or q3 =='b'):
    
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q3 =='C' or q3 =='c'or q3 =='A' or q3 =='a' or q3 =='D' or q3 =='d'):
    tsq3 = sq3 - 1
    score.pop(sq3)
    print("incorrect answer it is B.Allen Turing")
  else:
	  print("INVALID INPUT")

  input("PRESS ENTER TO CONTINUE")



  print("The first computers were programmed using?")
  q4 = input("A.Artificial Intelligence B.Assembly Language \nC.High-Level Language D.Machine Language \n")


  if (q4 =='D' or q4 =='d'):
    
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q4 =='B' or q4 =='b'or q4 =='A' or q4 =='a' or q4 =='C' or q4 =='c'):
    tsq4 = sq4 - 1
    score.pop(sq4)
    print("incorrect answer it is D.Machine Language")
  else:
    print("INVALID INPUT")
 
  input("PRESS ENTER TO CONTINUE")





  print("You organize files by storing them in?")
  q5 = input("A.Classes B.Folders \nC.Filers D.Documents \n")


  if (q5 =='C' or q5 =='c'):
  
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q5 =='B' or q5 =='b'or q5 =='A' or q5 =='a' or q5 =='D' or q5 =='d'):
    tsq5 = sq5 - 1
    score.pop(sq5)  
    print("incorrect answer it is B.Folders")
  else:
    print("INVALID INPUT")
 
  input("PRESS ENTER TO CONTINUE")





  print("UNIVAC is?")
  q6 = input("A.United Automation Computer B.Universal Adamantite Computer \nC. Universal Automatic Computer D.Unitarian Automated Computer \n")


  if (q6 =='C' or q6 =='c'):
    
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q6 =='B' or q6 =='b'or q6 =='A' or q6 =='a' or q6 =='D' or q6 =='d'):
    tsq6 = sq6 - 1
    score.pop(sq6)
    print("incorrect answer it is C. Universal Automatic Computer")
  else:
    print("INVALID INPUT")

  input("PRESS ENTER TO CONTINUE")
  dialogue2()





def dialogue2():
  input("\n \n \nWas it hard? let us make it harder \n PRESS ENTER TO CONTINUE \n")
  p3()





def p3():
  
  print("A CPU contains?")
  q7 = input("A.Control Unit and Arithmetic Logic Unit B.Motherboard \nC.Uknown Components D.one's and zeroes\n")


  if (q7 =='A' or q7 =='a'):
    
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q7 =='B' or q7 =='b'or q7 =='C' or q7 =='c' or q7 =='D' or q7 =='d'):
    tsq7 = sq7 - 1
    score.pop(sq7)
    print("incorrect answer it is A.Control Unit and an Arithmetic Logic Unit")
  else:
    print("INVALID INPUT")
 
  input("PRESS ENTER TO CONTINUE")




  print("a combination of hardware and software that facilitates the sharing of information between computing devices?")
  q8 = input("A. B. \nC. D.Network \n")


  if (q8 =='D' or q8 =='d'):
    
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q8 =='B' or q8 =='b'or q8 =='A' or q8 =='a' or q8 =='C' or q8 =='c'):
    tsq8 = sq8 - 1
    score.pop(sq8)
    print("incorrect answer it is D.Network")
  else:
    print("INVALID INPUT")
 
  input("PRESS ENTER TO CONTINUE")





  print("IBM 1401 is?")
  q9 = input("A.Second Generation Computer B. \nC. D. \n")


  if (q9 =='A' or q9 =='a'):
    
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q9 =='B' or q9 =='b'or q9 =='C' or q9 =='c' or q9 =='D' or q9 =='d'):
    tsq9 = sq9 - 1
    score.pop(sq9)
    print("incorrect answer it is A.Second Generation Computer")
  else:
    print("INVALID INPUT")
 

  input("PRESS ENTER TO CONTINUE")



  print("The capacity of 3.5 inch floppy disk is?")
  q10 = input("A.5.44 MB B.2 MB \nC.1.44 MB D.1 GB \n")


  if (q10 =='C' or q10 =='c'):
    
    print("SMART EINSTEIN KEEP IT UP!")
  elif(q10 =='B' or q10 =='b'or q10 =='A' or q10 =='a' or q10 =='D' or q10 =='d'):
    tsq10 = sq10 - 1
    score.pop(sq10)
    print("incorrect answer it is C.1.44 MB")
  else:
    print("INVALID INPUT")

  input("PRESS ENTER TO CONTINUE")
  dialogue3()





def dialogue3():
  input("\n \n \nHope you had a hard time and did not cheat. \n PRESS ENTER TO CONTINUE \n")
  GAME()



def GAME():
  print("Press enter for results.\n \n ", "Question 1 = ",tsq1,"\n  Question 2 = ",tsq2,"\n  Question 3 = ",tsq3,"\n  Question 4 = ",tsq4,"\n  Question 5 = ",tsq5,"\n  Question 6 = ",tsq6,"\n  Question 7 = ",tsq7,"\n  Question 8 = ",tsq8,"\n  Question 9 = ",tsq9,"\n  Question 10 = ",tsq10,"\n \n ", "Total score of: ",len(score))
# Out:
# Good Day Testee who might you be? a
# do you wish to test your knowledge? Y/N y
# The term ‘Computer’ is derived from?
# A.LATIN B.ENGLISH
# C.GREEK D.SPANISH
# a
# GOOD JOB SMART BUTT
# PRESS ENTER TO CONTINUE
# Who is the father of Computer?
# A.Rudy Siguenza B.Allen Turing
# C.Charles Babbage D.Edward Robert
# c
# SMART EINSTEIN KEEP IT UP!
# PRESS ENTER TO CONTINUE
#
#
#
# Congrats answering the easy questions let us make it harder
#  PRESS ENTER TO CONTINUE
#
# Who is the father of Computer science?
# A.Charles Babbage B.Allen Turing
# C.Edward Robert D.Albert Einstein
# a
# incorrect answer it is B.Allen Turing
# PRESS ENTER TO CONTINUE
# The first computers were programmed using?
# A.Artificial Intelligence B.Assembly Language
# C.High-Level Language D.Machine Language
# b
# incorrect answer it is D.Machine Language
# PRESS ENTER TO CONTINUE
# You organize files by storing them in?
# A.Classes B.Folders
# C.Filers D.Documents
# a
# incorrect answer it is B.Folders
# ...

# %%
def Result():
  len(score) 
  if len(score) <= 0:
    print("Did you even try?")
  elif len(score) <= 4:
    print("what's important is you Tried.")
  elif len(score)  >= 5:
    print("Knowledgable you are hmm.")
  elif len(score)  >= 8:
    print("Smart primate you deserve a banana.")

# %%
 
  sq1=0
  sq2=0
  sq3=1
  sq4=1
  sq5=1
  sq6=1
  sq7=1
  sq8=1
  sq9=1
  sq10=1
  score = [sq1,sq2,sq3,sq4,sq5,sq6,sq7,sq8,sq9,sq10]
  
  tsq3 = sq3 - 1
  print(tsq3)
  score.pop(sq2)
  print(score[sq1])
  print(score)
  len(score)
